# %% [markdown]
# # Probabilities

# %% [markdown]
# ## Kolmogorov's Axioms of probability

# %% [markdown]
# 1. For each outcome $w_i \in \Omega$, $P(w_i) \in [0,1]$.
# 2. For all outcomes $w_i \in \Omega, \Sigma_i P(w_i) = 1,$
# 3. For each event $E_j \subseteq \Omega, P(E_j) = \Sigma_i P(w_i)$, where $w_i \in E_j$,
# 4. For all possible disjoint events $E_j \subseteq \Omega$,
# <center>$P(\cup_j E_j) = \Sigma_j P(E_j)$</center>

# %%
from random import randint

# %%
print( randint(1, 6))
print( randint(1, 6))
print( randint(1, 6))
# Out:
# 6
# 5
# 4

# %%
n = 1000000
ne = 0

for i in range(n):
    outcome = randint(1,6)
    if(outcome == 3):
        ne+= 1
        
print("Prob =", round(ne / n, 4))
# Out:
# Prob = 0.1668

# %% [markdown]
# ## The Law of Large number

# %% [markdown]
# Let x_1, x_2, ..., x_n be a set of sample (realization/outcomes of a random experiement), then with probability 1:
# <center>$lim_{x\to\infty}\frac{x_1 + x_2 + ... + x_n}{n}$</center>
# converges to the population mean. That is, the running mean will eventually converge to the population mean.

# %% [markdown]
# ### Simulation program to study the running mean of the random experiement of tossing a coin

# %%
### Part 1: Performing the simulation experiement
from random import choice
from statistics import mean

n = 1000
observed = []

for i in range(n):
    outcome = choice(["Head", "Tail"])
    if outcome == "Head":
        observed.append(1)
    else:
        observed.append(0)
        
        print("Prob =", round(mean(observed), 2))
# Out:
# Prob = 0
# Prob = 0
# Prob = 0
# Prob = 0.2
# Prob = 0.58
# Prob = 0.57
# Prob = 0.56
# Prob = 0.53
# Prob = 0.53
# Prob = 0.5
# Prob = 0.48
# Prob = 0.52
# Prob = 0.5
# Prob = 0.5
# Prob = 0.48
# Prob = 0.47
# Prob = 0.47
# Prob = 0.49
# Prob = 0.47
# Prob = 0.47
# Prob = 0.46
# Prob = 0.46
# Prob = 0.45
# Prob = 0.44
# Prob = 0.43
# Prob = 0.42
# Prob = 0.41
# Prob = 0.4
# Prob = 0.4
# Prob = 0.39
# Prob = 0.4
# Prob = 0.41
# Prob = 0.4
# Prob = 0.39
# Prob = 0.4
# Prob = 0.39
# Prob = 0.39
# Prob = 0.39
# Prob = 0.39
# Prob = 0.42
# Prob = 0.42
# Prob = 0.43
# Prob = 0.43
# Prob = 0.43
# Prob = 0.42
# Prob = 0.43
# Prob = 0.43
# Prob = 0.43
# Prob = 0.44
# Prob = 0.46
# Prob = 0.46
# Prob = 0.46
# Prob = 0.46
# Prob = 0.45
# Prob = 0.46
# Prob = 0.46
# Prob = 0.46
# Prob = 0.45
# Prob = 0.45
# Prob = 0.45
# Prob = 0.45
# Prob = 0.45
# Prob = 0.45
# Prob = 0.46
# Prob = 0.45
# Prob = 0.45
# Prob = 0.46
# Prob = 0.46
# Prob = 0.46
# Prob = 0.46
# Prob = 0.46
# Prob = 0.46
# ...

# %%
### Part 2: computing the moving average

from numpy import cumsum

cum_observed = cumsum(observed)
moving_avg = []

for i in range(len(cum_observed)):
    moving_avg.append(cum_observed[i]/(i+1))
    
### Part 3: making the plot

from matplotlib.pyplot import *
from numpy import arange

x = arange(0, len(moving_avg), 1) # x-axis
p = [0.5 for i in range(len(moving_avg))]  # Line

xlabel("Iterations", size=20)
ylabel("Probability", size=20)

plot(x, moving_avg)
plot(x, p, linewidth=2, color="black")

show()
